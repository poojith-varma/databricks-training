# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("GoogleColabSpark") \
    .getOrCreate()

# %%
emp_df = spark.read.csv("/content/drive/MyDrive/Databricks/empData.csv",
header=True ,
inferSchema = True )
emp_df.show()
# Out:
# +------+------+------+-------+
# |emp_id|  name|salary|address|
# +------+------+------+-------+
# |     1|manish| 10000|  india|
# |     2|  rani| 20000|    usa|
# |     3| rinku| 55000|     uk|
# |     4|  neha| 12000|    usa|
# |     5| sneha| 20000|     uk|
# |     6| rahul| 30000|  india|
# +------+------+------+-------+

# %%
big_sales_df = spark.read.csv("/content/drive/MyDrive/Databricks/Big Sales.csv" ,
header =True,
inferSchema= True
)
big_sales_df.show()
big_sales_df.show(n=big_sales_df.count(), truncate=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# |FDI48          |11.85      |Regular         |0.0            |Baking Goods         |51.2666 |OUT035           |2004                     |Small      |Tier 2              |Supermarket Type1|410.1328         |
# |FDH09          |12.6       |Low Fat         |0.05616476     |Seafood              |51.8982 |OUT049           |1999                     |Medium     |Tier 1              |Supermarket Type1|473.3838         |
# |FDQ36          |7.855      |Regular         |0.0            |Baking Goods         |38.3848 |OUT046           |1997                     |Small      |Tier 1              |Supermarket Type1|932.12           |
# |FDY16          |18.35      |Regular         |0.092150005    |Frozen Foods         |184.8266|OUT013           |1987                     |High       |Tier 3              |Supermarket Type1|3872.9586        |
# ...
